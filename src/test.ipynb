# %%
import pytipeee as pt

# %%
creators = pt.Creators()
creators_list = creators.scrape(30)

# %%
creators_list
# Out:
# [{'translations': {'en': {'name': 'Naomi Wu- Shenzhen Maker, Tech and DIY Enthusiast.'}},
#   'id': 162339,
#   'slug': 'naomiwu',
#   'lang': 'en',
#   'status': 'OPEN',
#   'tags': [],
#   'categories': [{'translations': {'de': {'name': 'Geek & Nerd'},
#      'en': {'name': 'Geek'},
#      'es': {'name': 'Geek'},
#      'fr': {'name': 'Geek'},
#      'it': {'name': 'Geek'}},
#     'id': 36,
#     'slug': 'geek',
#     'name': 'Geek'},
#    {'translations': {'de': {'name': 'Wissenschaft & Technik'},
#      'en': {'name': 'Science & Technology'},
#      'es': {'name': 'Ciencia & Technologia'},
#      'fr': {'name': 'Sciences & Technologies'},
#      'it': {'name': 'Scienza & Tecnologia'}},
#     'id': 44,
#     'slug': 'science-technology',
#     'name': 'Science & Technology'}],
#   'avatar': {'id': 1370291,
#    'filename': '0be29d87b418c69dfdc2474445c16ae7de3d561b.jpg',
#    'updated_at': '2018-04-23T12:05:41+02:00'},
# ...
